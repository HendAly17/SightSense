# %% [markdown]
# Object Detection Goggles Training Code
# team:
# Shereen Mabrouk
# Alaa Hossam
# Abdelrahman Sewelam
# Hazem AbdelSalam
# Ahmed Ashraf
# Hend Khaled Aly

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)


import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/finaldataset/Dataset_new_all/data.yaml
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/green_263_jpg.rf.bff855f6fa3bb6194119d67065c2996e.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7531_jpg.rf.c71e8a7efd67a1a4f28745ae29d57314.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7345_jpg.rf.ae9296e84372d5c2c92a87b5bdd769ad.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7223_jpg.rf.4c04b199ab9d6323198ed136cf334b61.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7626_jpg.rf.d59454c8039dc3062bb305efffe6404d.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7379_jpg.rf.b294c0bde9f731067e9713920577a5c2.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7466_jpg.rf.f74073a995900281611455da9779780f.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7556_jpg.rf.ba943e9ac8743f27131aedc77134f220.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7445_jpg.rf.aa83cfee0f74c898b707c6dcad25252a.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7183_jpg.rf.2ce15fe7a5a6668c37425afdccded913.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/green_212_jpg.rf.503a5d772f736b82e75217036fc4a2f9.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7079_jpg.rf.2e494f7262c9c00d42c8304aa92d7b85.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7197_jpg.rf.8011bbd0a0f362efe679cf3616f17484.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7074_jpg.rf.b8b5c505ff98236fa4741ea66659d59f.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7349_jpg.rf.649bfbd08ea168a38433833fc004e80a.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7015_jpg.rf.cff56ebbfe7b3e452d9c9aba8a8451a0.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7414_jpg.rf.c60794a1043a85deba92ba511bc162af.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/a-339-_png_jpg.rf.f160249eeb4a0544ffbaa17c07c5bdda.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7217_jpg.rf.fcade0deffaa126fa32168fb70cf134e.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7552_jpg.rf.0fbf6f3c2f90d7ac1c359d48bebe7af5.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7551_jpg.rf.bde26942ef2aaf12b53b03aeb9680108.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7177_jpg.rf.1a100fe0e4d1f78c4fb2de5f21dee6aa.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7121_jpg.rf.ef77c324f7846059a9ed0fc264f0e8b7.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7187_jpg.rf.857e53fcfc9806ea85afe86b5ff25334.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles6897_jpg.rf.4085bdaaca17f1d5daab707175f7b653.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7038_jpg.rf.cca5977ac478bb9b314eaec51483232e.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7047_jpg.rf.595ddd6522bb9964679459719a54821d.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7547_jpg.rf.d2304cc297953c87097c9abf91a1e555.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7277_jpg.rf.16818f4c19657f8bc075bc55a1bbbf1d.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7332_jpg.rf.4cdac6b7c72c7708069aabe473d45458.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7532_jpg.rf.8ef3c23e755883b3d5db582279437027.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/96_png.rf.8824606d918ff103d0533e7bd232ccb2.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7096_jpg.rf.ef546d88d809a0bf7059f95baadfe874.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7119_jpg.rf.df58f86e6c91b906dfb2e2df52dc48c3.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/traffic-light-404-_jpg.rf.11f7dca39c29009c3579c9b15f447d3e.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/Screenshot-2023-12-13-at-7-29-41-PM_png.rf.fd494c57e2fee3b79d866e49194e586d.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/089_jpg.rf.f70419422702e27c7e613a9f89d01102.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7033_jpg.rf.8d37aa86c827f44e30daf8f3e28b34ac.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles6958_jpg.rf.12c5ce880c6ddabd885b2e69db148612.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7152_jpg.rf.1655eab68b781b940a51d423ecfa7b80.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/080_jpg.rf.ef2705b134bf755abea1e388176b3245.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/green_059_jpg.rf.26af75719376f5e4f1693bf1cf8bd774.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/green_105_jpg.rf.260faada944d4f6c6a908131163a8e45.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7317_jpg.rf.3fdd1b32c22b76c2e19648a363ea12f3.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7200_jpg.rf.a7dfd7f0e7251bffc939a77ef9e3c08a.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7255_jpg.rf.fe6b8d4b75ae3fd43f6ebf921ae49659.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7350_jpg.rf.be769a693013350f91ebb62151dc0035.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7530_jpg.rf.e04a504cfd3c0b29c2ee3e7ea95f27d1.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/15_jpeg_jpg.rf.861f970248b2c7005dce94ab00fe346f.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/2-13_jpg.rf.7809daa9b6e614ef6bacf3f7596efccc.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7323_jpg.rf.2899145bd0251eed84b094de16efb1d4.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles6916_jpg.rf.ae66952bb6255d749ac420df48d0950f.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7524_jpg.rf.adb2900e65a871878f2dbcee3e370de7.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7289_jpg.rf.bd08035bed97ee6f3f20f6e2a71ec532.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7341_jpg.rf.9d086268ac250d3292a2cbcaa0a71e97.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7155_jpg.rf.440dcda8e1f9e5a663286796fb3c1e74.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7580_jpg.rf.bad687cf9ea472b4ae26635051e423e9.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles6955_jpg.rf.52648d81034f84323f4247adf441e84d.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7339_jpg.rf.3296dcd10052ddb77bae757157a88ea4.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7173_jpg.rf.d5500f992e81eac6ee3f2989f31c560a.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7203_jpg.rf.9a8ab33f60d75b72bb29fdcea6eef6ec.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7146_jpg.rf.c940544ddf27def6b9c8e08dd5ef710e.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7540_jpg.rf.58cd9c7d094e5700b1210f6ba30ccde2.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/018_jpg.rf.c22bd4a8c74bc4185d0aa842ac6a0564.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/green_101_jpg.rf.3387d84f5946c18c3002ba87524de7a6.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/a-233-_png_jpg.rf.df8a634135187b7f25ae5c12174a0413.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7563_jpg.rf.65fc16e8a22619aa84792489cfb639d6.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7029_jpg.rf.25b5ec89b33bf7064fc07ded5e41eeda.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/images-4-_jpg.rf.07a7b13550c12d9427ce246010ef17a0.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7351_jpg.rf.271a8736b3ea784d704591e518d50b11.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7628_jpg.rf.06368664c7b6482718a254143d5ba9d1.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7493_jpg.rf.db06b98d334e874b639590fbb362f76c.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/traffic-light-12-_jpg.rf.fe274da0664fe5e14aa1683bd36e1fc0.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7523_jpg.rf.f304169750f26365de14047668b8d92b.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7352_jpg.rf.7a5811abaab2b096658e24475ae94cdc.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7418_jpg.rf.dc12408eac513ef2e1e4f11d81adca3b.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7561_jpg.rf.7bddf742f91b68247d3426500a84102c.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7120_jpg.rf.80ebbd8a3a55d021dab6fa501e741229.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles6922_jpg.rf.705fea0fc8109650a247f32581c4f10c.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7616_jpg.rf.34446c48a6fe173f7754ad7caaa7d14b.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7190_jpg.rf.70d2281a61fb8d07c564e061516cbf18.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7639_jpg.rf.56e286d80b208097ba5ded7c28eeb8ba.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7027_jpg.rf.1fe0e21986098c2dfdc1513321266365.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles6993_jpg.rf.10a10e0b396f6e6046a879ceaa63e0ee.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7331_jpg.rf.cb8c63330a6c793c2f26b0664faf3633.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7278_jpg.rf.fde29aeec092b8a2b24391739334c5b1.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/green_266_jpg.rf.e137b64645ad65c57449eb0909792aae.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7538_jpg.rf.40c6dc6048213672569f74f2fadc1a6f.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7330_jpg.rf.f07f52b8c10fe246590409139becba9c.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7210_jpg.rf.1b80b89b07e1e6b38a37d3be2b4b8c9b.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7254_jpg.rf.351063a4cb9fca5733f37b346a71695d.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/1-64-_jpg.rf.3cec72f37315c519b138511b6ddaf467.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/194_jpg.rf.a3ec0e8bf6018fc937576ec203e43dea.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7059_jpg.rf.24e50529aa677974f17271a06dca5c28.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7196_jpg.rf.aaed0436fc6a824665051b37cee741bf.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles6931_jpg.rf.f380f0445e0bd46df1a08432048f6b42.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7398_jpg.rf.3c3855b4db99aa227ac088ee4afcee34.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/green_189_jpg.rf.6e3f721da09870c64c797858de4bd816.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7041_jpg.rf.ca10b566228a4ed9c3bb960ee22401a9.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles6946_jpg.rf.33d5ae1483eca5b21563488fe55583b1.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/signal-light-22-_jpg.rf.0ddc79a7e791d85a3e9c7b1ddcd54651.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7140_jpg.rf.83dd15ceb171d12ade685764e3da4564.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7257_jpg.rf.2a1cd6fadf22ffb12aa1fcef3a63c0e1.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7380_jpg.rf.4a601301259606c3b0df0c2a18ff603a.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7020_jpg.rf.e7a8c99d305583a16b53698ea10e3d35.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7611_jpg.rf.e5605e4f5e266a957b90dc3865348040.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles6984_jpg.rf.9709cb64ed77872bc7c3d6382aa2597c.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7306_jpg.rf.13db537413dd2b3097db3526af290dbe.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7243_jpg.rf.180f6764fc1ebed9e625c0580119e109.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/Screenshot-2023-12-13-at-9-29-22-PM_png.rf.aef4a933a3e4421989f2de8bff765fb2.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7329_jpg.rf.f7269bd60a3350dae940eb884d164bb2.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/183_jpg.rf.fbfff82785f681024201d3ca3b30759b.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7159_jpg.rf.c54ea397bab4b39c59debafdddb7342f.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7594_jpg.rf.206634243c90c5c9b3b38fdf0b703a28.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7069_jpg.rf.81beaac71a39d5486f800275dd70b119.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7034_jpg.rf.624256529ee4027c4a6c41cb2d668b8b.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7076_jpg.rf.3c97780a7ef5a434b7edde00ffdff2e6.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7499_jpg.rf.231d262b7f63c1844e5f6594e782bd84.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7138_jpg.rf.5c747b6100937421fccfaea29b714b6a.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7392_jpg.rf.6b2743c9a168a75994d2acfd7b7df2a4.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles6881_jpg.rf.6ed06e5a67e8907a1469625a5769fc9d.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/-5E037376-5D27-4953-9841-0083E8D06D0B-png_jpg.rf.5e3597ee01ed2693ccc269cadebed106.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7584_jpg.rf.a8b1b23017aac5ee531a017185afad75.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7095_jpg.rf.b7b6bc7b2612e0ec1c7b291fd45d2d63.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/a-72-_png_jpg.rf.33b46117f2a45f0fc4d64d1a13209360.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7410_jpg.rf.2beb22c56d0c4688daab60190eecbf0e.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7637_jpg.rf.5384d8058081bcc09a728206a3c15870.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/12_jpeg_jpg.rf.668571186b29c27c3d680bf69733f2b8.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/images-5-_jpg.rf.4b69e4b3372c0305e5d7f5da03411851.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7031_jpg.rf.6dadd612a25c307e586c3da489b59435.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7503_jpg.rf.ef03806abab62bd54fbc791d895092f2.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles6986_jpg.rf.30af44ff22ecc8174f9768bf9d023731.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles6983_jpg.rf.d046ca7fd435f36fc586f452bf8859c0.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7412_jpg.rf.e01be32e7bc410fd0347f398c9e81eae.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles6932_jpg.rf.1746b21de5e427986d6a8bb8afaea27e.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7447_jpg.rf.3cbbcf8735fdab837e5823c4920587dc.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7487_jpg.rf.74905445c75f9b55d2f4910e7516f88b.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7045_jpg.rf.4759819755cfd9169155c3bd782876e2.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7526_jpg.rf.0056ef1a65a0417eeb58b94bd4984116.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7247_jpg.rf.961890f8ce75a541904b8059e2277c2b.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7111_jpg.rf.eb88f756ba112a0208c9a3bbf3626690.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles6957_jpg.rf.85bca2a519be4556452e4e22c7e07cd3.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7485_jpg.rf.eef89eb2330b5dfd2db1da5f25a09e2e.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7100_jpg.rf.0a88af5505765d9dcab92838ee953823.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7072_jpg.rf.3435aa04bf4382e6da93130784c251d8.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7092_jpg.rf.50407ac6cdeb02f924a1cfb1b874eae1.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/lampu-kuning-54-_jpg.rf.d143bf3d168a02529503e005dae7c13c.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/traffic-light-260-_jpg.rf.33fa763d767b21f2007625df7201c1d0.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7543_jpg.rf.5994b783959f9e8adabf3fe5e82a2884.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7089_jpg.rf.ee69ceb4547126fb8d00f8cad775cceb.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7253_jpg.rf.0c58e330fa79d4c605e176d5a753db9b.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles6885_jpg.rf.46cdf7c7d74788f91d0cdc635ac270dd.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7557_jpg.rf.f74d7386b281889b464cbe7b3d497ab2.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7315_jpg.rf.c109c77c60fd2cb191863408af75b711.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7048_jpg.rf.d37e2f50948794754c35d1771930f913.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7263_jpg.rf.677022843300682868a41a8670215f5d.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7106_jpg.rf.dd11bf89bd8912d59ae54ac427809783.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/16_jpg.rf.46b8a35daf5a76cbf83e223994aa41c5.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7550_jpg.rf.9eecc881d696ba552cdb05144d6645fa.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/-046E9840-F025-4749-B3AB-19402B34E739-png_jpg.rf.968610dbec68e05f4a0978562ff36d89.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7061_jpg.rf.50d9df9b2ec3a9113bdc50b31e5a0558.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7060_jpg.rf.0a392fe9ff14f40aa179fcdecb6c9640.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7109_jpg.rf.eeca001a531a1d754bf3c69067f42cd6.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7354_jpg.rf.228688ef5606ff18832e38bc251ddc7b.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/lampu-kuning-64-_jpg.rf.20a94076270c0f13d20846591ed030bb.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7515_jpg.rf.f2063e3f923851f4860fb35a2af7f781.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/download-2-_jpg.rf.f9a4c06df0f5b8e2e5ffc05443df020a.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/signal-light-113-_jpg.rf.08f4b772cb24a13dcb13f0474b319261.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles6930_jpg.rf.6a8f40c3d37fd5ef95de76a4366643e3.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7483_jpg.rf.ca2e559df6551140a5b964d2613c4c5f.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7438_jpg.rf.547b10657cc3bddd31a8e5a4a31565cb.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7310_jpg.rf.8146c5610850facc3a5b44407546abf9.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/-5541726B-201F-4295-A6CB-AA0F566A62F9-png_jpg.rf.4c5000c43878ca9d4c442f9fec19a44a.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles6921_jpg.rf.f614a642a6006fb4da23e6cdb9b522c9.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7458_jpg.rf.853409ad68815105108d949f5dc920a5.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7122_jpg.rf.9f048c18383c98c62e1b2419f37fdb7e.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7080_jpg.rf.7c013bcc72defb2b6d4b2eba7cc43518.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7214_jpg.rf.96b75a93a77fe7959b854526ad93df6b.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/maxresdefault-15_jpg.rf.afba2334aa38b13ab65f4b453b6cb87d.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles6969_jpg.rf.ce94039fdc0b7875b42133dfc43b9871.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/128_jpg.rf.bc62ba11a5fde9d66aaf4df8df9c3c8a.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7163_jpg.rf.b3a11271136e6e9f81e1e7ecc5876cd6.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7382_jpg.rf.51861220c23009edbab053c7de67a6fc.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/25_png.rf.069f91aa4149debeb9afd535f3baadde.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/246_jpg.rf.022acb24844582909e9f0f9049f6b976.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7572_jpg.rf.db32da9ca7aac5c9a32dd8c8a87c227e.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/241_jpg.rf.94ce13b002bcc3be41d73fcdb65a2cb8.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7001_jpg.rf.5bf12624a14258f9029e6d09bbce82d7.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles6905_jpg.rf.91a5e0048808fc612ab3f2944e6dd1b4.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7602_jpg.rf.33b6eae1db326ce9d9048c2ad1f5eb63.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7582_jpg.rf.4d4f6becd766d98fd4683497c2b8cb6f.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles6994_jpg.rf.f778961e867ed63c0881a71ebbebad7e.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7094_jpg.rf.3e87a3d43e0944f49aa6564ecc519776.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles6987_jpg.rf.83732b7b6bd3a63f29c5e25b3aa0984e.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7164_jpg.rf.6f3db4656598659bc662c12c7e03da47.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles6914_jpg.rf.2fba3348c22bf2ca97f67fcbb5b60d96.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles6949_jpg.rf.5cd32bb874a392e4a165b65798f41086.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7261_jpg.rf.b164f2d5a59a7948c22210a2a2dc98a9.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/Screenshot-2023-12-13-at-9-44-13-PM_png.rf.448872b857b9b6b63e6bf50508fb97e2.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/-3923D79E-9339-4D23-97E0-76DC2B526C3C-png_jpg.rf.f96011c53086c6ffdfdf0bcd922cd28e.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7264_jpg.rf.80394d6949a446023e23ce3a956a23cf.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/temporary-traffic-lights-street-england-34609671_jpg.rf.9f27a2cc567ca6472ec81775151283e2.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7101_jpg.rf.24662378037bcf9b9ac33f6d0bf03c6c.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7338_jpg.rf.f2bd6356dbbecdc7684eae65dfdd4b1d.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7359_jpg.rf.13bd1c1ecd2d21a545eb58d10ed6edc5.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7613_jpg.rf.4c6044e7cfebc26ee9bc37028aa24255.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7226_jpg.rf.d94bb423f802de2f577b610bd75766cf.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7461_jpg.rf.2464493da80248fe390fdfc9b149920b.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/27_jpg.rf.9986800b982d6dc3bb0cf88cdb613c14.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7402_jpg.rf.7e83e2e44ab147abea3703c213d8a794.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7577_jpg.rf.9c198698e908f46ccbb36c723185f182.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7394_jpg.rf.0a6a68b846ffd31c48312e6ca25e2122.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7166_jpg.rf.6e43f26d8d5a3e00f1e37463d3bacb03.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7312_jpg.rf.7d18b4ddb84b6950bc788ee322bf6584.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7494_jpg.rf.7595f5bd80a1496a1853cb299790e4b1.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7148_jpg.rf.16a23463b69dd854127f779ce86fec50.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/traffic-light-shows-stop-25238863_jpg.rf.aebc9b15bd2083479d5d3e8a947e9265.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7230_jpg.rf.674b05b962d7d3c8220097726f9da700.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles6892_jpg.rf.3fe8275022bc4da1de0b8871c8cb1752.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles6900_jpg.rf.8c8b77dff9d109855726613f48aeabc6.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7268_jpg.rf.1dcd3798363b535ebd933bf658fe2a29.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7240_jpg.rf.83d51b0e151b1481fc7d1738be63370e.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7206_jpg.rf.49ae539d4076a9c5c6ca295f35c89756.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7597_jpg.rf.c9e300b95ff1b78f11e5604caab7db9c.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/Screenshot-2023-12-13-at-9-45-48-PM_png.rf.300b7efca1bccd1d835dd8b06806121f.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7615_jpg.rf.4a5032c1d31ceb2bd173ba1928147d29.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/-BABD5091-6597-40E1-82D1-29A0F4DCD9E0-png_jpg.rf.e58a6513194960f776088abed864b806.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/green_226_jpg.rf.d18d8de589c0827de54e8486ade30aeb.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7564_jpg.rf.6ae658001a49663b2e9e2217efd1a22a.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7137_jpg.rf.17fb0f015a0e223db8825113470f318d.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7376_jpg.rf.3c05218d85a696dc2fb21fd5d48d2cb6.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7612_jpg.rf.a92900538179420df1b800bb8e9c3cfa.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/2015-mitsubishi-fuso-fe180-dual-tech_jpg.rf.415142c209032baa47ab630f941dac5c.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7186_jpg.rf.3bc1aeec854cb64d1c91ee5dbbc25f3b.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7107_jpg.rf.294372df7f6342e703173a1e0d44b271.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7457_jpg.rf.32f42246421efce4b39a120656b70c68.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7576_jpg.rf.ae7bf5a82372294c36434f247b126a15.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/53_png.rf.bcf0fd6d812e3d368549fd634d8be7e4.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/traffic-light-824-_jpg.rf.9bc8dce40bc2b0a4c46f23dd38e657b7.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7242_jpg.rf.5848600f6b7b16cd60797bced77036db.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7065_jpg.rf.c0eba426cf0b0cb010179678ef5b0a88.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7056_jpg.rf.5dedcfde3284d548e12a585c20e509b7.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7198_jpg.rf.bf3101edc8f2cb8aff053cab2f64f1ad.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/traffic-light-surveillance-camera-pole-mounted-street-79351054_jpg.rf.d6e7108743015355179d6cb410fe179a.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7178_jpg.rf.02c178bcde1bebdacf29d2d0a302908a.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7307_jpg.rf.99a01f02deabf9fa8f46123bbdf0457e.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7102_jpg.rf.456cb45693ae0aa503b8c859d791a63c.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7248_jpg.rf.57f3b4f00137f50a11885373612ede64.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7302_jpg.rf.6c5e50737fd1bbb1fe34cb2bcbb3ef1e.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7117_jpg.rf.e8263c7b3a6f4fc5df78be2d642a0b1f.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7467_jpg.rf.5aa98dacb3d835d6971b1cf48cd62544.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/green_303_jpg.rf.8f285d4938bef99a47528e928ccd3116.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/-1B59F314-F3FE-4352-A076-48D5D98B1372-png_jpg.rf.dc2c74a4573e0fdef544a1d8a2a5692d.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles6913_jpg.rf.e707d3bb7d1aaec91c45f5a2d29d4ded.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/Screenshot-2023-12-13-at-7-52-27-PM_png.rf.7e16fa8bd3c937f55c503cd61427d6e2.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7344_jpg.rf.4bc2d6ea40ab58f9c494099837e55091.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7108_jpg.rf.c907ef9022d5359cd3c87409e03c29fc.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7275_jpg.rf.9d8fee0dfb48111e61a2c3e4169528a4.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7093_jpg.rf.015a37d0694cf04ee5e8a826f90e6c7d.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7558_jpg.rf.9e58c345ae0b88984a840f847610849e.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7003_jpg.rf.f02a3c6905d3ee1e01d4422e6fb6fe30.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles6934_jpg.rf.4c5bb77b9c2ac6d7f2d20849eb09f705.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7103_jpg.rf.fcfa82207113d354e07c90138d5884c1.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7081_jpg.rf.a40da7d359ff16749a67648d55781806.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/20210528_10_41_42_000_2sQ7uoDSHQakPcTTKy9Ikfs5wWs1_F_3264_2448_jpg.rf.306e50865a8e176a21fd9c3a51d1912f.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/green_252_jpg.rf.bb56a839bc81459b50b8485f11e230f7.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7063_jpg.rf.8d17ae1f91c2bdd9a1a6147b9d5d01c7.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles6977_jpg.rf.6eac8617ec7bc7c57004cee045c3407d.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7237_jpg.rf.16dd9659cd25bfda95f807036fadb546.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/lampu-kuning-34-_jpg.rf.37804d80ad927afe5b9bf5b23536a440.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7162_jpg.rf.d6a34f9bc1d62ba9599062eda99f5c36.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7021_jpg.rf.4d881c44d5c18fa9ff17e1c13dd88b4a.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7465_jpg.rf.f2cc40c897e8920670000f8eb10e9f2f.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7542_jpg.rf.34b46b5eb6ebddd03b8feb2c37d3ad06.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7478_jpg.rf.ce74cbd9f383a731a0bc3390d65d3f16.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7236_jpg.rf.a837a3c935144ee2578f077359cc08db.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7225_jpg.rf.c72993f06686beac8ed3af1e7dc3e4ef.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7409_jpg.rf.d7dfdaa14d1d9460b232c00f69380bab.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7154_jpg.rf.e9831db53112b84e17af09ef2786a91c.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/signal-light-64-_jpg.rf.388ad01e3159542af7bd616e40c0c16d.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7326_jpg.rf.491889fb0b4b202276e4b67753b97d1a.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/-5DB86A4E-D64A-4032-ACF4-957B38D438C9-png_jpg.rf.3ec97ecfdc70ef5af238f68c300ec1f3.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7627_jpg.rf.143a4dca665b8bda7d920b4d15280d7a.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7581_jpg.rf.09ac3d9e77a1e270d14451292fbff6e9.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7194_jpg.rf.8ba2f906bd52f6b06ed60a2a6aa6239d.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles6929_jpg.rf.9b11241676c87e1f0fd0954e5b66b342.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7085_jpg.rf.1ffc275a6d477e3ffaead3182eb512e4.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7151_jpg.rf.3080f2ba9ba3204054aa4c84cb22c99b.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7356_jpg.rf.a949c33c6aa9cab0f946ae22177aa97d.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/14_jpeg_jpg.rf.a1c5b1f0840a5c57940f3d41f893eea1.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7032_jpg.rf.65912c70e7a5297e55d80b10b1c8d550.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7327_jpg.rf.fab131d78da8dfdfa028e95bbba14976.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7595_jpg.rf.95cddffb08432707720e3b11c0a3ab0d.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/31_png.rf.4be3c580d3a6b441a42499f2482b9841.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/199_jpg.rf.e44b56900ef620447cc31d533736d008.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles6966_jpg.rf.61235a08eb8bdf4fdad1282034be3288.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/green_047_jpg.rf.bb68c552e2d48d471b6f4f8ec4f54918.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7030_jpg.rf.a705ae1541b2e3a49b3585c30a66e837.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/green_273_jpg.rf.3e16a906308c9010c4be8dee67f55b81.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/20210429_14_22_24_000_M0qQbjq7mhasETXjCQGvnoZxK3a2_F_4160_3120_jpg.rf.f78a51d88626f42ada0468417b39eccc.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7241_jpg.rf.5b19bd4bc4bd18e4220a78bd8df76e77.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/signal-light-26-_jpg.rf.536bc5a19b4c7d3fb1ed4df576de9dc4.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7541_jpg.rf.f9d421b780dfc657c21cc990fa8a6b20.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7136_jpg.rf.c340aac6ad0c2b982e02e89cdc22101c.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles6928_jpg.rf.3385412e172f51628f8c69426b9130e2.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles6888_jpg.rf.175c9499e950b0a94631782376063743.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7053_jpg.rf.f25e7c7d25857b3dd94f0ff5b70a17af.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7199_jpg.rf.57d09c0a93915e434063146fbc48a6bb.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7168_jpg.rf.c3ecc1c8c552d8277d817775013ea539.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/green_151_jpg.rf.e8628d83a6bd7e27f6dcbf158aec834a.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/lampu-merah-45-_jpg.rf.1d77b7e99632b9c8563b30b5bd179531.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/green_305_jpg.rf.c225e09d0528444c432d4db7bf114870.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7321_jpg.rf.bdb2a462eb19b27ebafcfb1497987303.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7404_jpg.rf.89c41b83c7996fa76c3c5017ac28f24e.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7066_jpg.rf.876a0b53a24a651efe05981ed38ae0dc.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7273_jpg.rf.4ba89f8ba02ecbb539be2afa48916b63.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7573_jpg.rf.7d41f2bc6b159ac5ac06f57480e54d4f.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7036_jpg.rf.b51f3e228c10a03074be467ec91c4d59.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7131_jpg.rf.4330bb80b59eb5ed24bf4614a0347f59.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7175_jpg.rf.6e8248ce69d7aab7a36774ce608bb8a7.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7296_jpg.rf.fb1ffc289e79c9ef50c4e48b4c75479b.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7437_jpg.rf.c73c88efc18a203a77eca038f3c62d6b.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7422_jpg.rf.dbf9eacb98b2d65e00656d2267570cbf.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/104_jpg.rf.074fad2a25c2db34253dcc709743bd8f.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7374_jpg.rf.8d0d1bb070cc4daf211d6592091cb993.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7562_jpg.rf.748ec4f48983dde69bcdb452565c1c18.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7182_jpg.rf.d3128862c5287f5e78c58ea859dc3804.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles6933_jpg.rf.f6e2c0c14f26ef8c4f6d43a83bf17523.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7057_jpg.rf.818d42e924906a5d9a0bf46077adf0bd.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/green_082_jpg.rf.2ea26ab4b0364597e7950a7657e78980.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/images-3-_jpg.rf.944ad8109839031d6c827f527bc10605.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7476_jpg.rf.52de6d09a8f3799f4657d7974f422bc9.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/green_048_jpg.rf.2d3540e8bfe4310c3b48487828229914.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7215_jpg.rf.0dea6ec7b3a4f7011d657dfdd34b62bd.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7536_jpg.rf.abc5bfe9313d74bcfe8ba5961a7b571c.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles6868_jpg.rf.652c797d3a123bb7c863229cc8f4ef33.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7234_jpg.rf.c9bd63271a862508456991187b3b178c.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/140_jpg.rf.0e9ee2cdd32f23d51f8272f7727ed6f2.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/green_205_jpg.rf.c8474e36c3431f4379db5ae5a6a7430e.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/traffic-light-143-_jpg.rf.e89a15ef7b6f7a04c6a9d7772c02e03d.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles6940_jpg.rf.03d515b6b91d5aa839958bb847d40ee0.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/-E1655382-7FF5-4725-9C33-D894A3A0881E-png_jpg.rf.f3f70a5500db7396e396762976c6c357.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7520_jpg.rf.fc8066c7991e6e69d66035c4f2fe5a60.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/Screenshot-2023-12-13-at-9-02-40-PM_png.rf.f3a455066349306e8a5b9006bc2e13bb.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7017_jpg.rf.a473afc2d92945f6325bf054db03e6eb.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7400_jpg.rf.a441004256f8a8cbb77d3a0c46109267.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7239_jpg.rf.d848f9665adbad3add4e2baea55fc7d5.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/a-61-_png_jpg.rf.aad2c94427733e3ee1ac98f9ff328f45.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7049_jpg.rf.96d2b990121615ac02695ad745ce342d.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7471_jpg.rf.e75e5e46c56d0b04dd953b0d90484ca3.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles6992_jpg.rf.cd4693d04af80d99e4834128f1ac4403.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7219_jpg.rf.56b73cfd14f507f30033a19bc184eedd.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles6899_jpg.rf.091f951f9a17aea2c5b620491657fb99.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/WhatsApp-Video-2023-05-05-at-16-45-16_out0026_jpg.rf.b8f11da39d3b11fc0b3fb15df7ce452a.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7636_jpg.rf.fc621983e2afc0c49629d4ca2c52bf28.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7192_jpg.rf.2c992d945a3d353004a196bbb0188367.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/-3571FC71-85E8-4968-8882-3A4B92AC8388-png_jpg.rf.a0fd3759160bf7add4c54758c70d40f1.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/-0B43DB53-2377-4D6D-B5B8-60CBBAB90F88-png_jpg.rf.04e65a36c579de6246ecfcacac11bf56.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7477_jpg.rf.0cb263d21156c74e5e7f4797d50438a4.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7533_jpg.rf.d0d8c6f7edd4128e80db763678e47b76.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles6960_jpg.rf.e5297d89973a5f5fb0cf764a9ff0e5de.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7204_jpg.rf.67bdfecdfd024d344238a1331491b05c.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/175_jpg.rf.bc561f9939b32fa702eb38e10c0089e4.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7322_jpg.rf.13a76b83495f496263da4075d991cc7b.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles6894_jpg.rf.3aa3bdb5d088175d9dece5b4e8bf2aec.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7522_jpg.rf.697ca6da925879ad02184d024263fd8c.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7633_jpg.rf.63838c8b741e34edbfb75bb4f28961f0.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7428_jpg.rf.4908e86159fffc5055e3a6327c258c56.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7291_jpg.rf.e1d575aca416a6d288782fbf6c0037ae.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles6945_jpg.rf.fbd9077c2038597c5d6c8e0fe50e9fa0.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles6873_jpg.rf.50815a59e685b96982d19fe1b957e174.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7062_jpg.rf.8add44f1875cfaa4829364df3f4c9ddd.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7508_jpg.rf.5137cbda8dcb0ee3a001e2f40d85c2f8.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7346_jpg.rf.26fd777ee57e17f972c728876b5a3d3d.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7527_jpg.rf.12bfdaccbe0711e3473ab6961bae2b57.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7502_jpg.rf.1ce5ca063cbe038d59fc6054879c1bd5.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7431_jpg.rf.44edb932e46e254e60955b9c446aebe1.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7405_jpg.rf.42597be829db8034d490fa004945f996.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/018_jpg.rf.aa2b5d5bb64869b78cce831503706fc4.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7084_jpg.rf.74a221d8645656b8f968eaeccb6abc72.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7383_jpg.rf.c018986538e8a9c0fd5ef18dbb495536.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7559_jpg.rf.bccbb045004d52eeb20c4d7a55219c28.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/trafficlight152_png_jpg.rf.09290b2b1d6553f46e19f246f7d2b4fa.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7019_jpg.rf.79b1fed8782ad21dca0f3b4ce56c8160.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7424_jpg.rf.1a4261ce1cdf40b1d5543d010b55e84c.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7391_jpg.rf.566fd803328045476e789cfb974e82cd.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7070_jpg.rf.093e515f30dcd0d6deb4dd2616e30296.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles6952_jpg.rf.e2839844cede94baec5d7cd879278fa6.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7313_jpg.rf.8499b26d402157a254bf1bc7f64d1674.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7232_jpg.rf.32172d2a3c68684d57e61435dc2cf6d3.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7270_jpg.rf.d9c5f56e2d7e033b690b9948bb03215a.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7479_jpg.rf.40fc9ef38e66ea40fd43f58e3131daa4.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/186_jpg.rf.c025db8b8cb959c81afac40c8bcc3b79.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7620_jpg.rf.0a80e062938147f3f7b8a544f0e424d8.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7586_jpg.rf.ac45958d218ccbd1c75630eea4adc282.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles6980_jpg.rf.475bd18c41223e98d829d2774ba0975d.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7436_jpg.rf.1acc6e82498a462fdef651fd4288ea89.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7008_jpg.rf.39b0490b0a5ab65b937c4cb7c329b7f4.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/trafficlight184_png_jpg.rf.f1541438f8a05f5520235ea18d40cbae.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/Image_013269_jpg.rf.45e154f963d5b5ac0a95ddd9b96e6da5.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/2_jpg.rf.566381059c830c59ad38cdaf6fcdfcda.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/traffic-light-143-_jpg.rf.6928082f7efbc552e31a4795eb417002.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/a-195-_png_jpg.rf.501a9e55b2f48d58dc3283681a169791.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/-CF18C7DF-3DC1-4F14-A3B1-8521CEE36C3E-png_jpg.rf.938d57f889e4a483c5d23cf3125d304c.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7490_jpg.rf.3cc2b5d10fdce17d6aa67c0b0000f596.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles6979_jpg.rf.ab5adef95e4268e687d45e5dc592bcbe.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/032_jpg.rf.eb704febbabc7f3c403925ac11a07b09.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7629_jpg.rf.6c182cb19e49e758636d247ffeae368d.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7463_jpg.rf.f11333640359900c7e504713d854a612.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7150_jpg.rf.404806efd4a5d3670c8435a7cb2c56ab.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7363_jpg.rf.5109a34c08d83b20bae0e22e70c82735.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7266_jpg.rf.46ba3a360076ab4c593ef1c031bdce06.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7090_jpg.rf.5eea3f06fe34ee809310f9db0448a040.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/WhatsApp-Image-2023-05-06-at-14-44-20-6-Copy_jpeg_jpg.rf.58918a9dcbe7d2fe460424c54b70802b.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/traffic-light-968-_jpg.rf.4d91944ea0bb071cb2645224d4b271f4.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7370_jpg.rf.8cf8ecc65bb2a0317b053707ee18bf2c.txt
# /kaggle/input/finaldataset/Dataset_new_all/test/labels/loserfiles7587_jpg.rf.ab0e1d97e8bb4cf47207125fb026f41d.txt
# ...
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles2048_jpg.rf.01b680163ecb4ea33c3ae8424a534749.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles3313_jpg.rf.a2f2d8f815816dcd12952c30eb2dff91.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles5962_jpg.rf.9505a5a3d52f7ed4ea3520579de70f08.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles5996_jpg.rf.04dce164851675f729bbb835b4d3a24f.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/119_jpg.rf.320374fdf0dbe85bca39679bdf5c8111.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles6828_jpg.rf.5eb57348257ea2865ade1c9a4321d950.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/signal-light-23-_jpg.rf.b5013e87a76a9f803de3e5809d97943b.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles3260_jpg.rf.1b685c40a348174cba5a1767fb6a57db.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles4955_jpg.rf.c698bf0ce41436e90052c6ed9fd8c875.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles5177_jpg.rf.9af72dd0b27e2a6112ee066401356df5.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles3841_jpg.rf.cd9e2afbff8f2f57b3c6ca4ec3b27d6b.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles2490_jpg.rf.bb7124a3ae6048ea2f6da1bbeabda5ea.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles5040_jpg.rf.bc219575139b998a1f0bf7197e3c61fd.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles2860_jpg.rf.ed14dc3a35d1961f90148f0e88a95ec1.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles3495_jpg.rf.a9a5693699132a3c63f2708af8411415.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles6627_jpg.rf.920dee9654f77dccbf9a40bb635f7479.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles1752_jpg.rf.29b06ca4820a5afe1c3c48b9ecc9fb4a.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/81_png.rf.082034dd166ee72ada8a07c3a883003e.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/sold-20-09-10-0730193a_jpg.rf.eeb89732e2aaaf90dd93d021025fe8e9.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles5150_jpg.rf.02f24fd6d7e3b0ee5ac01047acbece3d.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/35_jpeg.rf.ce956408fa178c177acc3d61ea8e1d4d.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles1858_jpg.rf.6764581a65df47f93d5bfadd15b8b112.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/-496DFB6F-CD96-44F4-8CF4-683733EC79B6-png_jpg.rf.7f00b0daa13f1d4da1a0839e6d7b9c51.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/a-144-_png_jpg.rf.f0c67219becd088ded634079108fa936.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles4793_jpg.rf.ee8bd59fc741f6cfdad690e49dc6ae6d.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/Image_013438_jpg.rf.ae6876d7f839dcca03a1d8619967c4cb.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/66_jpg.rf.fb82615650fd65b2953a16139f059825.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles6799_jpg.rf.4d6ef53abfc79a01a3c659a3e003408a.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles4599_jpg.rf.a6b810b212a4f73478256d9ae1dc9940.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles4696_jpg.rf.dab819137d149b5eefbe2b30404f8b8f.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles4577_jpg.rf.789530fde5a7ca00560b81e266952c6f.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles4588_jpg.rf.0ad9c3f02c5950aea7b88993153c7bbf.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles2447_jpg.rf.e3866e2b87fb2616b1a828617f507b14.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles2412_jpg.rf.d7282751b55491a1a6b705577315bdc0.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles1822_jpg.rf.102eaf2f826ea70f2ba1a2e2099bbd4c.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/green_185_jpg.rf.d9bd9072875f8298a4bff786fb1a4189.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles1735_jpg.rf.0ec08e831e14f1a95fd2906aa9f9ffaa.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles2791_jpg.rf.ccbc009a430b8dfe0e71f17ce0ac1923.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/20210519_04_16_48_000_RMkLr8rWJDMBfnDv6WRtqfoMLT83_T_4160_3120_jpg.rf.f4d82aea68ff589f7030ef2084258cf4.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles1543_jpg.rf.bd40624f0ef9fadba1b16b3dddd689a5.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles117_jpg.rf.4ebcd96d93b5a1f2b9ef5df0cc3a131a.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles1908_jpg.rf.8e2bf97afe1967d18b00a9627ca2078f.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles6650_jpg.rf.9332e9d4b1bed9e8515990dda3e2e5d0.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles3469_jpg.rf.cb01aca08fc1054a319dcdd5da2b78f7.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles5737_jpg.rf.bfa980ee784b220094911a676bfb60d4.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles4729_jpg.rf.475f1de1dc2c7ce5a2f45cc214c84723.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles5108_jpg.rf.250b2517fb2ad977056d3502f5343253.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/AKR20230307047400053_02_i_P2_jpg.rf.4e7fac8cc8956554020d3c55adc34c6b.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles379_jpg.rf.68e9fc5066bc74d2367ab81649f7bf57.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles4053_jpg.rf.edb7fac5a2298a53f4df6c8e0074e901.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles3071_jpg.rf.0659b363789d546d5486145418ce3433.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles4853_jpg.rf.4110bf1df0e6949895e46e24e41dc526.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/Stop_Light_Wide_jpg.rf.b71a31a3b90e4b7489aaa74328a01708.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles3175_jpg.rf.8e968a83faf3f1cab858df85921306ed.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles3792_jpg.rf.ac8c9a2507db355d8dc80455e3ba2260.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/Screenshot-2023-12-13-at-7-52-38-PM_png.rf.f393ffd986a5ade4334fe6f7946c7e96.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles2657_jpg.rf.3493644690099c11fc500bbd0dee6145.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles66_jpg.rf.cffe09f8171da7aeff815c6f279bf589.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles5514_jpg.rf.5f4de3f357e1a400fa4b37ac3c30a9b8.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/t7_jpg.rf.00eb4e256cdb7c1b7b4f84ac79fabd89.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles1601_jpg.rf.5c687504596237d9dbf4ac07bf4a3bdf.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles6004_jpg.rf.e62b2291c67927f3bc37fe1787792e0b.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles4160_jpg.rf.c23b54f264ef66900fedb10032496218.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles6731_jpg.rf.5e3486434b79610c5bf3a3f20b6f7a1b.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles5994_jpg.rf.6383621c7c944ed5f91457403259224f.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles5748_jpg.rf.7267bbcc6be0f284bea181b0f69fa9fa.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles312_jpg.rf.5b542e35e829c749de9f076aa62dc76d.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/a-301-_png_jpg.rf.0ac52bc18f019e733ebcf576e300a286.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles4259_jpg.rf.295b03289789b173f96fb1c5b2a6d700.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles2822_jpg.rf.d067f751cb65985fc54398cb09f67b64.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles3947_jpg.rf.693e07adeab1e393b120e11c4d1d0bd0.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles5614_jpg.rf.22368203fad3d5689b376488fa3b7945.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles224_jpg.rf.8a42ca3327aef6deaba07692af69d340.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/signal-light-88-_jpg.rf.575c0c58290122886aa3491550a7ff06.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles6662_jpg.rf.009c602024c1ca3178ab85e08ec523dc.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles5165_jpg.rf.c4aca52a36459eaf557c9dc03620af13.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/Screenshot-2023-12-13-at-7-19-16-PM_png.rf.c434513db8983edf327b96101e2dcf3c.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/Screenshot-2023-12-13-at-7-05-53-PM_png.rf.5ed2f32ca790ce500c4c429f28bdd3c9.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles5566_jpg.rf.e562a98176cba66ea9b741f63dc6189e.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles5530_jpg.rf.95108009d0cd0fd377a30afb435a9040.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles5779_jpg.rf.766d2cb1668df6fbf028ed3d133f687d.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles6413_jpg.rf.b0c0260bebbc655793ff6916c47efa56.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles3954_jpg.rf.672c2540e07c4030aa3a44b7143fc633.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles2474_jpg.rf.420d7957edb5dc62f91f1a93a161f2df.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles5246_jpg.rf.a1bd69de5ed76aa130b7963dc31afe05.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/green_066_jpg.rf.2a944f94b3bdaeeadc7b4ea67fa27084.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles5057_jpg.rf.199a3b9d88f1ac45c02c67d72dab5415.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles4159_jpg.rf.0f9b32e756b4443f55227eaa82a7e6b3.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/Image_013593_jpg.rf.d15d763b8096119b8783963e4e47a598.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles4692_jpg.rf.a76dcb916262e0655f7286c0499c6c29.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/Screenshot-2023-12-13-at-7-54-42-PM_png.rf.4553db9a13e63df373430d7bad5fbeaf.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles772_jpg.rf.af770cb6d792b907bb10fd4227dac91b.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles2834_jpg.rf.01dd17d73193829a1d1629c4eca4f2c9.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles4194_jpg.rf.28cbc393e67641a592e11df0c4b68eef.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/Modifikasi-2BTruk-2BIndonesia-2B10_jpg.rf.08d31221dac6dca07887ff913ac279ef.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles2873_jpg.rf.1937505de18ff98aaa2f8dedd7c089b0.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles990_jpg.rf.117c6baeb4097e5090d5c2091b40b47c.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles4959_jpg.rf.95eb4dbf654a94b47b9026c1b94814ab.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/23_jpg.rf.eff054f9cb3724527d5cb5513ce12e1d.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles2871_jpg.rf.f3367b2a702b93d041a6056f03cea482.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/bus-90-_jpg.rf.fc4701f9c1b24ffd438f51bec88b0128.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles1043_jpg.rf.909571613f4303dd386799a53832fa82.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles5440_jpg.rf.20bb0b14f509ef51e2e887ca92450ba4.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles4851_jpg.rf.0cb72f0de30140fbf32bad4c7273a171.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/green_127_jpg.rf.1138e58841dfad7514a28ef37c2a5f4a.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles6357_jpg.rf.22d2b76910a4aa72f8dc902046409cc5.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles3370_jpg.rf.bf0efb5629ab2b7a0a167b68312174f3.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/211_jpg.rf.f88d4e56f49cf3a1311552ea0a9d505b.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles6646_jpg.rf.13c8d65d8c1d748ee3dc169c9f5d4001.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles5525_jpg.rf.e8eae09f33edcfbb8d5cd3ebb2df9832.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles166_jpg.rf.ec25a8e11e82c84c10ef1cf7200b23a0.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles2849_jpg.rf.3513fdd11f07eb0bba90d4ae4bf8eebb.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles4082_jpg.rf.1bc1a5a3fa64bf3fa78c25a22094088e.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles5275_jpg.rf.1dbe94650307148530b9146d0f3cb79e.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles2749_jpg.rf.eb84e3e7a1db456330cdebdf8eb09f8f.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles6781_jpg.rf.5b7bc00e3c3c6865b4b843d86cba5280.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles3239_jpg.rf.a48739611747bc24349f8bf79843f7e1.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/-DE24E442-B2F4-43B7-8741-6AA037A20D4E-png_jpg.rf.a10beb0f492aa54271cd4bffc80a1407.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles1787_jpg.rf.1cd2b8514db92a1727f2152ac99700cf.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles2907_jpg.rf.ea326c5ed8d476634173c55b35c6e6f5.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles1145_jpg.rf.92fc8e007afe70e7f617323e1434a5e5.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles5390_jpg.rf.f6a0784bb5cd95ec7294885c97a9acbe.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles4595_jpg.rf.e5b3ad0f4aae97dc5e0b79de9f169842.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles2078_jpg.rf.55e28f4febe64331ec3f32e1bb50a222.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles714_jpg.rf.4bd2be7d8df7d51f2175d8804435370f.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles2619_jpg.rf.10ea9d0c9fb47ae05b2da713a6488ef6.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles5882_jpg.rf.eefecabb571e2cf85526ca1ade7cf162.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles4812_jpg.rf.ceb7116bcc7c0212af3a42d795c87b2f.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/54_png.rf.32ac12e1c8cf31956918b4f0744bc951.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/green_148_jpg.rf.ee48b517a7dd9dfadd86838f3610d32f.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles3237_jpg.rf.982e8e021faf4d2d7c998f4784d201d9.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/Beverage-Trucks-Mitsubishi-Fuso-FG-1_jpg.rf.055b4d9c7dfcc8205fa29eec9c6f5c2c.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles1398_jpg.rf.d52f1cac5e4f4e72916ade172817a63c.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles5493_jpg.rf.3828b33a2db5a95d1ba12943474ccd75.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles4995_jpg.rf.8b5ade8f339b1dfbd66e58db3b8d47f6.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles1717_jpg.rf.dd5d97ac2b20633c453698668f3d108d.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/signal-light-91-_jpg.rf.0dac1c8a0b0c5460fb9a6e62edb1e6ba.jpg
# /kaggle/input/finaldataset/Dataset_new_all/train/images/loserfiles3879_jpg.rf.a0dd0ffb1dfb036451d5e9cb43a67bed.jpg

# %%
import os
import matplotlib.pyplot as plt
import cv2
import shutil
import numpy as np 
import pandas as pd 
import datetime
from pathlib import Path
from collections import Counter
import yaml
from sklearn.model_selection import KFold
import glob
from PIL import Image

# %%
# Define a mapping of class numbers to their names
class_names = {
    0: 'Autorickshaw',
    1: 'Barricades',
    2: 'Bench',
    3: 'crosswalk',
    4: 'fire-hydrant',
    5: 'garbage',
    6: 'garbage box',
    7: 'pothole',
    8: 'stairs',
    9: 'stray animal',
    10: 'green_light',
    11: 'red_light',
    12: 'vehicles'
}

# %%
def count_class_train(label_folder_train):
    class_counts = {class_number: 0 for class_number in range(13)}
    if os.path.exists(label_folder_train):
        os.chdir(label_folder_train)
        for label_file in os.listdir(label_folder_train):
            label_file_path =  label_file
            #label_file_path = label_file_path.replace('\\','/')
            with open(label_file_path, 'r') as file:
                lines = file.readlines()
                for line in lines:
                    class_number = int(line.split()[0])
                    class_counts[class_number] += 1
    else:
        print('directory not found')
    return class_counts

dump="/kaggle/input/finaldataset/Dataset_new_all/train/labels"
train_class_occurrences = count_class_train(dump)

for class_number, occurrence in train_class_occurrences.items():
    class_name = class_names.get(class_number)
    print(f'Class {class_name} ({class_number}) : {occurrence}')
# Out:
# Class Autorickshaw (0) : 2354
# Class Barricades (1) : 2782
# Class Bench (2) : 1292
# Class crosswalk (3) : 1898
# Class fire-hydrant (4) : 766
# Class garbage (5) : 1616
# Class garbage box (6) : 1734
# Class pothole (7) : 1662
# Class stairs (8) : 1602
# Class stray animal (9) : 2221
# Class green_light (10) : 1118
# Class red_light (11) : 1042
# Class vehicles (12) : 1672

# %%
def count_class_test(label_folder_test):
    class_counts = {class_number: 0 for class_number in range(13)}
    if os.path.exists(label_folder_test):
        os.chdir(label_folder_test)
        for label_file in os.listdir(label_folder_test):
            label_file_path = label_file
            with open(label_file_path, 'r') as file:
                lines = file.readlines()
                for line in lines:
                    class_number = int(line.split()[0])
                    class_counts[class_number] += 1
    else:
        print("directory not found")

    return class_counts

dump2='/kaggle/input/finaldataset/Dataset_new_all/test/labels'
test_class_occurrences = count_class_test(dump2)

for class_number, occurrence in test_class_occurrences.items():
    class_name = class_names.get(class_number)
    print(f'Class {class_name} ({class_number}) : {occurrence}')
# Out:
# Class Autorickshaw (0) : 118
# Class Barricades (1) : 86
# Class Bench (2) : 104
# Class crosswalk (3) : 80
# Class fire-hydrant (4) : 82
# Class garbage (5) : 147
# Class garbage box (6) : 107
# Class pothole (7) : 90
# Class stairs (8) : 81
# Class stray animal (9) : 111
# Class green_light (10) : 102
# Class red_light (11) : 40
# Class vehicles (12) : 86

# %%
# Create a bar chart to visualize the class occurrences
classes = list(train_class_occurrences.keys())
counts = list(train_class_occurrences.values())

# Map class numbers to their names for labeling the x-axis
class_labels = [class_names.get(class_number, 'Unknown') for class_number in classes]

# Increase figure size for better readability
plt.figure(figsize=(12, 6))

# Create the bar chart with integer values for occurrences
plt.bar(class_labels, counts)
plt.xlabel('Class Name')
plt.ylabel('Occurrences')
plt.title('Class Occurrences in Training Set')

# Rotate x-axis labels for better visibility
plt.xticks(rotation=45)
plt.tight_layout()

# Display integer values on top of each bar
for i, v in enumerate(counts):
    plt.text(i, v, str(v), ha='center', va='bottom')

plt.show()

# %%
# Create a bar chart to visualize the class occurrences
classes = list(test_class_occurrences.keys())
counts = list(test_class_occurrences.values())

# Map class numbers to their names for labeling the x-axis
class_labels = [class_names.get(class_number, 'Unknown') for class_number in classes]

# Increase figure size for better readability
plt.figure(figsize=(12, 6))

# Create the bar chart with integer values for occurrences
plt.bar(class_labels, counts)
plt.xlabel('Class Name')
plt.ylabel('Occurrences')
plt.title('Class Occurrences in Test Set')

# Rotate x-axis labels for better visibility
plt.xticks(rotation=45)
plt.tight_layout()

# Display integer values on top of each bar
for i, v in enumerate(counts):
    plt.text(i, v, str(v), ha='center', va='bottom')

plt.show()

# %%
TARGET_IMAGES_PATH = '/kaggle/working/detection/full_dataset/images/'
TARGET_LABELS_PATH = '/kaggle/working/detection/full_dataset/labels/'

source_folder_path = "/kaggle/input/finaldataset/Dataset_new_all/{split}/{type}"
splits = ["train"]
types = ["images/*.jpg", "labels/*.txt"]

os.makedirs(TARGET_IMAGES_PATH, exist_ok=True)
os.makedirs(TARGET_LABELS_PATH, exist_ok=True)

image_paths = list()
label_paths = list()

for split in splits:
    for data_type in types:
        files = glob.glob(source_folder_path.format(split=split, type=data_type))
        for file_ in files:
            if "image" in data_type:
                shutil.copy(file_, TARGET_IMAGES_PATH)
            else:
                shutil.copy(file_, TARGET_LABELS_PATH)

# Store image and label paths for future use
image_paths = glob.glob(TARGET_IMAGES_PATH + "*.jpg")
label_paths = glob.glob(TARGET_LABELS_PATH + "*.txt")

# %%
dataset_path = Path('/kaggle/working/detection/full_dataset/') # replace with 'path/to/dataset' for your custom data
labels = sorted(dataset_path.rglob("*labels/*.txt")) # all data in 'labels'

# %%
import yaml

yaml_file = '/kaggle/input/finaldataset/Dataset_new_all/data.yaml'  # your data YAML with data directories and names list
with open(yaml_file, 'r', encoding="utf8") as y:
    data = yaml.safe_load(y)

# Assuming 'names' is a list of strings
classes = data.get('names', [])#############was sorted############
cls_idx = {index: name for index, name in enumerate(classes[:13])}
print(cls_idx)
print(classes)
# Out:
# {0: 'Autorickshaws', 1: 'Bench', 2: 'Crosswalk', 3: 'Firehydrant', 4: 'Person', 5: 'Barricade', 6: 'Garbage box', 7: 'Pothole', 8: 'Stairs', 9: 'Stray animal', 10: 'green_light', 11: 'red_light', 12: 'vehicles'}
# ['Autorickshaws', 'Bench', 'Crosswalk', 'Firehydrant', 'Person', 'Barricade', 'Garbage box', 'Pothole', 'Stairs', 'Stray animal', 'green_light', 'red_light', 'vehicles']

# %%
indx = [l.stem for l in labels] # uses base filename as ID (no extension)
labels_df = pd.DataFrame([], columns=cls_idx, index=indx)

# %%
for label in labels:
    lbl_counter = Counter()

    with open(label,'r') as lf:
        lines = lf.readlines()

    for l in lines:
        # classes for YOLO label uses integer at first position of each line
        lbl_counter[int(l.split(' ')[0])] += 1

    labels_df.loc[label.stem] = lbl_counter

labels_df = labels_df.fillna(0.0) # replace `nan` values with `0.0`
# Out:
# /tmp/ipykernel_34/2598033761.py:13: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   labels_df = labels_df.fillna(0.0) # replace `nan` values with `0.0`

# %%
# !pip install iterative-stratification
from iterstrat.ml_stratifiers import MultilabelStratifiedKFold
# Out:
# Collecting iterative-stratification
#   Downloading iterative_stratification-0.1.7-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from iterative-stratification) (1.26.4)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from iterative-stratification) (1.11.4)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.10/site-packages (from iterative-stratification) (1.2.2)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->iterative-stratification) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->iterative-stratification) (3.2.0)
# Downloading iterative_stratification-0.1.7-py3-none-any.whl (8.5 kB)
# Installing collected packages: iterative-stratification
# Successfully installed iterative-stratification-0.1.7

# %%
data = labels_df.iloc[:, 0:].values

our_labels = (data > 0).astype(int)

ksplit = 5

mskf = MultilabelStratifiedKFold(n_splits=ksplit, shuffle=True, random_state=42)
kfolds = mskf.split(data, our_labels)

# %%
folds = [f'split_{n}' for n in range(1, ksplit + 1)]
folds_df = pd.DataFrame(index=indx, columns=folds)

for idx, (train, val) in enumerate(kfolds, start=1):
    folds_df[f'split_{idx}'].loc[labels_df.iloc[train].index] = 'train'
    folds_df[f'split_{idx}'].loc[labels_df.iloc[val].index] = 'val'
# Out:
# /tmp/ipykernel_34/3825890032.py:5: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   folds_df[f'split_{idx}'].loc[labels_df.iloc[train].index] = 'train'
# /tmp/ipykernel_34/3825890032.py:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   folds_df[f'split_{idx}'].loc[labels_df.iloc[val].index] = 'val'

# %%
fold_ratios_list = []

# Iterate over each fold
for fold, (train_idx, val_idx) in enumerate(mskf.split(data, our_labels)):
    train_labels = our_labels[train_idx]
    val_labels = our_labels[val_idx]
    fold_ratios = {'Fold': fold + 1}
    for i in range(our_labels.shape[1]):
        train_count = np.sum(train_labels[:, i])
        val_count = np.sum(val_labels[:, i])

        # Compute the ratio
        ratio = val_count / train_count if val_count > 0 else np.nan  # Using NaN for undefined ratios
        fold_ratios[f'Class_{i}_Ratio'] = ratio

    # Add ratios for this fold to the list
    fold_ratios_list.append(fold_ratios)

# Create a DataFrame from the list
ratios_df = pd.DataFrame(fold_ratios_list)

# %%
supported_extensions = ['.jpg', '.jpeg', '.png']

# Initialize an empty list to store image file paths
images = []

# Loop through supported extensions and gather image files
for ext in supported_extensions:
    images.extend(sorted((dataset_path / 'images').rglob(f"*{ext}")))

# Create the necessary directories and dataset YAML files (unchanged)
save_path = Path(dataset_path / f'{datetime.date.today().isoformat()}_{ksplit}-Fold_Cross-val')
save_path.mkdir(parents=True, exist_ok=True)
ds_yamls = []

for split in folds_df.columns:
    # Create directories
    split_dir = save_path / split
    split_dir.mkdir(parents=True, exist_ok=True)
    (split_dir / 'train' / 'images').mkdir(parents=True, exist_ok=True)
    (split_dir / 'train' / 'labels').mkdir(parents=True, exist_ok=True)
    (split_dir / 'val' / 'images').mkdir(parents=True, exist_ok=True)
    (split_dir / 'val' / 'labels').mkdir(parents=True, exist_ok=True)

    # Create dataset YAML files
    dataset_yaml = split_dir / f'{split}_dataset.yaml'
    ds_yamls.append(dataset_yaml)

    with open(dataset_yaml, 'w') as ds_y:
        yaml.safe_dump({
            'path': split_dir.as_posix(),
            'train': 'train',
            'val': 'val',
            'names': classes
        }, ds_y)

# %%
for image, label in zip(images, labels):
    for split, k_split in folds_df.loc[image.stem].items():
        # Destination directory
        img_to_path = save_path / split / k_split / 'images'
        lbl_to_path = save_path / split / k_split / 'labels'

        # Copy image and label files to new directory (SamefileError if file already exists)
        shutil.copy(image, img_to_path / image.name)
        shutil.copy(label, lbl_to_path / label.name)

# %%
PATH1 = '/kaggle/working/detection/full_dataset/2024-03-14_5-Fold_Cross-val/split_3'
os.listdir(PATH1)
# Out:
# ['train', 'split_3_dataset.yaml', 'val']

# %%
file_path = '/kaggle/working/detection/full_dataset/2024-03-14_5-Fold_Cross-val/split_3/split_3_dataset.yaml'  # Replace with the actual path to your file

try:
    with open(file_path, 'r', encoding='utf-8') as file:
        file_contents = file.read()
        print(file_contents)
except FileNotFoundError:
    print(f"File '{file_path}' not found.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# names:
# - Autorickshaws
# - Bench
# - Crosswalk
# - Firehydrant
# - Person
# - Barricade
# - Garbage box
# - Pothole
# - Stairs
# - Stray animal
# - green_light
# - red_light
# - vehicles
# path: /kaggle/working/detection/full_dataset/2024-03-14_5-Fold_Cross-val/split_3
# train: train
# val: val

# %%
import os
from collections import Counter

folder_path = '/kaggle/working/detection/full_dataset/2024-03-14_5-Fold_Cross-val/split_3/train/images'

# Get a list of all files in the folder
files = os.listdir(folder_path)

# Extract file extensions and count occurrences
file_extensions = [os.path.splitext(file)[1] for file in files]
extension_counts = Counter(file_extensions)

# Print the file formats and their counts
print("File Formats and their counts:")
for extension, count in extension_counts.items():
    print(f"{extension}: {count}")
# Out:
# File Formats and their counts:
# .jpg: 13727

# %%
folds_df.to_csv(save_path / "kfold_datasplit.csv")
#ask about that folder
#fold_lbl_distrb.to_csv(save_path / "kfold_label_distribution.csv")

# %%
pip install ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.1.27-py3-none-any.whl.metadata (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.3/40.3 kB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib>=3.3.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (3.7.5)
# Requirement already satisfied: opencv-python>=4.6.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (4.9.0.80)
# Requirement already satisfied: pillow>=7.1.2 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (9.5.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (1.11.4)
# Requirement already satisfied: torch>=1.8.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (2.1.2)
# Requirement already satisfied: torchvision>=0.9.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (0.16.2)
# Requirement already satisfied: tqdm>=4.64.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (4.66.1)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from ultralytics) (5.9.3)
# Requirement already satisfied: py-cpuinfo in /opt/conda/lib/python3.10/site-packages (from ultralytics) (9.0.0)
# Collecting thop>=0.1.1 (from ultralytics)
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: pandas>=1.1.4 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (2.1.4)
# Requirement already satisfied: seaborn>=0.11.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (0.12.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.20 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (21.3)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.1.4->ultralytics) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.1.4->ultralytics) (2023.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (2024.2.2)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (3.13.1)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (4.9.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (3.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (2024.2.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)
# Downloading ultralytics-8.1.27-py3-none-any.whl (721 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 721.2/721.2 kB 31.5 MB/s eta 0:00:00
# Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Installing collected packages: thop, ultralytics
# Successfully installed thop-0.1.1.post2209072238 ultralytics-8.1.27
# Note: you may need to restart the kernel to use updated packages.

# %%
from ultralytics import YOLO, checks, hub
checks()  # checks
# Out:
# Ultralytics YOLOv8.1.27 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla P100-PCIE-16GB, 16276MiB)
# Setup complete ✅ (4 CPUs, 31.4 GB RAM, 5518.9/8062.4 GB disk)

# %%
os.chdir("/kaggle/working/")

# %%
models = YOLO("yolov8n.pt")
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.1.0/yolov8n.pt to 'yolov8n.pt'...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 240MB/s]

# %%
import os
import shutil

# Define the source and destination paths
source_path = '/kaggle/input/finaldataset/Dataset_new_all'
destination_path = '/kaggle/working/'

# Create the destination directory if it doesn't exist
if not os.path.exists(destination_path):
    os.makedirs(destination_path)

# Copy the directories (train and test) and data.yaml
for item in os.listdir(source_path):
    source_item = os.path.join(source_path, item)
    destination_item = os.path.join(destination_path, item)

    if os.path.isdir(source_item):
        # Copy entire subdirectory
        shutil.copytree(source_item, destination_item)
    else:
        # Copy file (e.g., data.yaml)
        shutil.copy2(source_item, destination_item)

print("Dataset copied successfully.")
# Out:
# Dataset copied successfully.

# %%
os.chdir("/kaggle/working/")
#hub.login('fa8f8014c4c2c475e025f962f622f0c2e79149cfb4')  # use your API key
#model = YOLO('yolov8n.yaml')  # Build a model from scratch
results = models.train(data="/kaggle/working/detection/full_dataset/2024-03-14_5-Fold_Cross-val/split_3/split_3_dataset.yaml",epochs=100)  # train model
# Out:
# Ultralytics YOLOv8.1.27 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla P100-PCIE-16GB, 16276MiB)
# engine/trainer: task=detect, mode=train, model=yolov8n.pt, data=/kaggle/working/detection/full_dataset/2024-03-14_5-Fold_Cross-val/split_3/split_3_dataset.yaml, epochs=100, time=None, patience=100, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf'...
# 100%|██████████| 755k/755k [00:00<00:00, 67.4MB/s]
# 2024-03-14 22:18:43,842	INFO util.py:124 -- Outdated packages:
#   ipywidgets==7.7.1 found, needs ipywidgets>=8
# Run `pip install -U ipywidgets`, then restart the notebook server for rich notebook output.
# 2024-03-14 22:18:44,680	INFO util.py:124 -- Outdated packages:
#   ipywidgets==7.7.1 found, needs ipywidgets>=8
# Run `pip install -U ipywidgets`, then restart the notebook server for rich notebook output.
# 2024-03-14 22:18:47.120360: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-14 22:18:47.120484: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-14 22:18:47.270967: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Overriding model.yaml nc=80 with nc=13
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    753847  ultralytics.nn.modules.head.Detect           [13, [64, 128, 256]]
# Model summary: 225 layers, 3013383 parameters, 3013367 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs/detect/train', view at http://localhost:6006/
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# AMP: checks passed ✅
# train: Scanning /kaggle/working/detection/full_dataset/2024-03-14_5-Fold_Cross-val/split_3/train/labels... 13727 images, 0 backgrounds, 0 corrupt: 100%|██████████| 13727/13727 [00:10<00:00, 1260.13it/s]
# train: New cache created: /kaggle/working/detection/full_dataset/2024-03-14_5-Fold_Cross-val/split_3/train/labels.cache
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 217, len(boxes) = 17399. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# val: Scanning /kaggle/working/detection/full_dataset/2024-03-14_5-Fold_Cross-val/split_3/val/labels... 3434 images, 0 backgrounds, 0 corrupt: 100%|██████████| 3434/3434 [00:02<00:00, 1255.11it/s]
# val: New cache created: /kaggle/working/detection/full_dataset/2024-03-14_5-Fold_Cross-val/split_3/val/labels.cache
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 45, len(boxes) = 4360. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# Plotting labels to runs/detect/train/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: SGD(lr=0.01, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# TensorBoard: model graph visualization added ✅
# Image sizes 640 train, 640 val
# Using 4 dataloader workers
# Logging results to runs/detect/train
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100       2.4G      1.252      3.264       1.54         43        640: 100%|██████████| 858/858 [02:49<00:00,  5.07it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:23<00:00,  4.57it/s]
#                    all       3434       4360      0.494      0.483       0.49      0.271
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      2.41G      1.311      2.388      1.568         47        640: 100%|██████████| 858/858 [02:41<00:00,  5.31it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:21<00:00,  5.12it/s]
#                    all       3434       4360      0.521      0.446      0.449      0.228
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100       2.4G      1.405      2.296      1.643         42        640: 100%|██████████| 858/858 [02:38<00:00,  5.41it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:21<00:00,  5.11it/s]
#                    all       3434       4360      0.528       0.38      0.386       0.18
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100       2.4G      1.476      2.227      1.706         37        640: 100%|██████████| 858/858 [02:37<00:00,  5.45it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:20<00:00,  5.16it/s]
#                    all       3434       4360      0.575      0.457      0.455      0.227
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100      2.39G      1.423      2.007      1.661         33        640: 100%|██████████| 858/858 [02:37<00:00,  5.45it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:20<00:00,  5.21it/s]
#                    all       3434       4360      0.621      0.505      0.534      0.285
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100      2.39G      1.373      1.833      1.619         27        640: 100%|██████████| 858/858 [02:37<00:00,  5.45it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:20<00:00,  5.14it/s]
#                    all       3434       4360      0.651      0.575      0.605      0.335
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100      2.39G      1.344      1.707      1.594         46        640: 100%|██████████| 858/858 [02:38<00:00,  5.43it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:20<00:00,  5.23it/s]
#                    all       3434       4360      0.675      0.577      0.634      0.349
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100      2.39G      1.316      1.629      1.575         40        640: 100%|██████████| 858/858 [02:37<00:00,  5.44it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:20<00:00,  5.18it/s]
#                    all       3434       4360      0.657      0.624      0.654      0.383
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100      2.39G      1.294      1.565      1.554         43        640: 100%|██████████| 858/858 [02:37<00:00,  5.45it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:20<00:00,  5.18it/s]
#                    all       3434       4360      0.646      0.637       0.66      0.384
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100      2.38G      1.276      1.506      1.546         47        640: 100%|██████████| 858/858 [02:37<00:00,  5.45it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:20<00:00,  5.18it/s]
#                    all       3434       4360      0.636      0.643      0.671      0.397
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100      2.39G      1.254      1.457      1.524         38        640: 100%|██████████| 858/858 [02:37<00:00,  5.44it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:21<00:00,  5.10it/s]
#                    all       3434       4360      0.712      0.666      0.718      0.427
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100      2.38G      1.238      1.426      1.509         44        640: 100%|██████████| 858/858 [02:37<00:00,  5.45it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:20<00:00,  5.19it/s]
#                    all       3434       4360      0.712      0.673      0.721      0.439
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/100      2.38G      1.225      1.395      1.501         36        640: 100%|██████████| 858/858 [02:37<00:00,  5.44it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:20<00:00,  5.16it/s]
#                    all       3434       4360      0.698      0.685      0.725      0.446
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/100      2.38G      1.219      1.352      1.485         37        640: 100%|██████████| 858/858 [02:37<00:00,  5.44it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:20<00:00,  5.23it/s]
#                    all       3434       4360      0.739      0.678      0.739      0.456
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/100      2.38G      1.198      1.317      1.477         35        640: 100%|██████████| 858/858 [02:37<00:00,  5.45it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:20<00:00,  5.28it/s]
#                    all       3434       4360      0.767      0.688      0.744      0.463
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/100      2.38G      1.193      1.294      1.467         36        640: 100%|██████████| 858/858 [02:37<00:00,  5.44it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:20<00:00,  5.16it/s]
#                    all       3434       4360       0.72      0.701      0.743      0.464
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/100      2.38G       1.19       1.28      1.471         49        640: 100%|██████████| 858/858 [02:37<00:00,  5.44it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:20<00:00,  5.20it/s]
#                    all       3434       4360      0.762      0.715      0.757      0.475
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/100      2.38G       1.18       1.26      1.456         34        640: 100%|██████████| 858/858 [02:38<00:00,  5.41it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:21<00:00,  5.02it/s]
#                    all       3434       4360      0.768      0.715      0.768      0.484
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/100      2.38G      1.162      1.241      1.448         43        640: 100%|██████████| 858/858 [02:38<00:00,  5.40it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:21<00:00,  5.08it/s]
#                    all       3434       4360      0.743      0.736      0.776      0.495
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/100      2.38G       1.16      1.224      1.441         35        640: 100%|██████████| 858/858 [02:39<00:00,  5.39it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:21<00:00,  5.13it/s]
#                    all       3434       4360      0.735      0.724      0.767      0.491
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/100      2.38G      1.152      1.192      1.433         37        640: 100%|██████████| 858/858 [02:38<00:00,  5.40it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:21<00:00,  5.12it/s]
#                    all       3434       4360      0.772       0.72      0.783      0.503
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/100      2.38G      1.138      1.174      1.424         38        640: 100%|██████████| 858/858 [02:39<00:00,  5.37it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:20<00:00,  5.17it/s]
#                    all       3434       4360      0.778       0.73      0.794      0.515
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      23/100      2.38G      1.136      1.166      1.428         41        640: 100%|██████████| 858/858 [02:39<00:00,  5.38it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:20<00:00,  5.16it/s]
#                    all       3434       4360      0.778      0.744       0.79       0.51
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      24/100      2.38G      1.121      1.156      1.417         52        640: 100%|██████████| 858/858 [02:39<00:00,  5.37it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:21<00:00,  5.03it/s]
#                    all       3434       4360      0.771      0.761      0.795      0.524
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      25/100      2.38G      1.128      1.138      1.416         35        640: 100%|██████████| 858/858 [02:40<00:00,  5.36it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:20<00:00,  5.22it/s]
#                    all       3434       4360      0.805      0.744      0.808      0.528
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      26/100      2.38G      1.116      1.123      1.411         46        640: 100%|██████████| 858/858 [02:37<00:00,  5.44it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:20<00:00,  5.24it/s]
#                    all       3434       4360       0.78      0.763      0.804      0.529
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      27/100      2.38G      1.112       1.11      1.405         33        640: 100%|██████████| 858/858 [02:38<00:00,  5.41it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:21<00:00,  5.09it/s]
#                    all       3434       4360      0.796       0.75      0.811      0.537
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      28/100      2.38G      1.108      1.107      1.402         44        640: 100%|██████████| 858/858 [02:38<00:00,  5.41it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:20<00:00,  5.14it/s]
#                    all       3434       4360      0.787      0.766      0.817       0.54
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      29/100      2.38G      1.102      1.089      1.395         50        640: 100%|██████████| 858/858 [02:38<00:00,  5.41it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:21<00:00,  5.14it/s]
#                    all       3434       4360       0.79      0.764      0.811       0.54
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      30/100      2.38G      1.096      1.079      1.391         30        640: 100%|██████████| 858/858 [02:38<00:00,  5.40it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:21<00:00,  5.13it/s]
#                    all       3434       4360      0.787      0.773      0.817      0.543
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      31/100      2.38G       1.09      1.065      1.387         48        640: 100%|██████████| 858/858 [02:38<00:00,  5.40it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:20<00:00,  5.17it/s]
#                    all       3434       4360      0.815      0.776      0.831      0.554
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      32/100      2.38G      1.088      1.057      1.387         37        640: 100%|██████████| 858/858 [02:38<00:00,  5.40it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:21<00:00,  5.11it/s]
#                    all       3434       4360       0.79      0.786      0.827      0.552
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      33/100      2.38G      1.081      1.037      1.379         50        640: 100%|██████████| 858/858 [02:38<00:00,  5.41it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:20<00:00,  5.21it/s]
#                    all       3434       4360      0.789      0.784      0.828      0.559
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      34/100      2.38G       1.07      1.037      1.376         51        640: 100%|██████████| 858/858 [02:38<00:00,  5.40it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:20<00:00,  5.17it/s]
#                    all       3434       4360      0.789      0.794      0.832      0.563
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      35/100      2.38G      1.077      1.036      1.374         43        640: 100%|██████████| 858/858 [02:38<00:00,  5.41it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:20<00:00,  5.17it/s]
#                    all       3434       4360      0.805      0.781      0.835      0.565
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      36/100      2.38G      1.063      1.014      1.364         46        640: 100%|██████████| 858/858 [02:38<00:00,  5.43it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:20<00:00,  5.22it/s]
#                    all       3434       4360      0.804      0.792      0.835      0.568
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      37/100      2.38G      1.063      1.011      1.367         30        640: 100%|██████████| 858/858 [02:38<00:00,  5.41it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:21<00:00,  5.13it/s]
#                    all       3434       4360      0.797      0.802      0.839      0.569
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      38/100      2.38G      1.057      1.002      1.361         45        640: 100%|██████████| 858/858 [02:38<00:00,  5.40it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:21<00:00,  5.12it/s]
#                    all       3434       4360      0.801      0.795      0.841      0.572
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      39/100      2.38G      1.058     0.9952      1.357         33        640: 100%|██████████| 858/858 [02:39<00:00,  5.38it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:20<00:00,  5.20it/s]
#                    all       3434       4360      0.814      0.794      0.844      0.577
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      40/100      2.38G      1.047      0.975      1.353         38        640: 100%|██████████| 858/858 [02:38<00:00,  5.42it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:20<00:00,  5.20it/s]
#                    all       3434       4360      0.822       0.79      0.846      0.576
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      41/100      2.38G      1.045     0.9848      1.351         42        640: 100%|██████████| 858/858 [02:37<00:00,  5.43it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:20<00:00,  5.23it/s]
#                    all       3434       4360      0.815      0.802      0.852      0.584
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      42/100      2.38G      1.046     0.9729      1.349         42        640: 100%|██████████| 858/858 [02:38<00:00,  5.43it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:21<00:00,  5.13it/s]
#                    all       3434       4360      0.812      0.805       0.85      0.582
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      43/100      2.38G      1.037     0.9668      1.345         30        640: 100%|██████████| 858/858 [02:38<00:00,  5.41it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:21<00:00,  5.14it/s]
#                    all       3434       4360       0.81      0.807      0.851      0.586
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      44/100      2.38G      1.031     0.9517      1.339         35        640: 100%|██████████| 858/858 [02:38<00:00,  5.42it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:20<00:00,  5.29it/s]
#                    all       3434       4360      0.817      0.811      0.851      0.586
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      45/100      2.38G       1.03     0.9494      1.339         35        640: 100%|██████████| 858/858 [02:38<00:00,  5.42it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:20<00:00,  5.20it/s]
#                    all       3434       4360      0.822      0.806      0.851      0.586
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      46/100      2.38G       1.03     0.9455      1.336         26        640: 100%|██████████| 858/858 [02:38<00:00,  5.42it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:20<00:00,  5.26it/s]
#                    all       3434       4360      0.817      0.809      0.851      0.591
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      47/100      2.38G      1.022     0.9359      1.334         27        640: 100%|██████████| 858/858 [02:37<00:00,  5.44it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:20<00:00,  5.21it/s]
#                    all       3434       4360      0.822      0.817      0.857      0.592
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      48/100      2.38G      1.014     0.9258      1.331         43        640: 100%|██████████| 858/858 [02:37<00:00,  5.44it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:20<00:00,  5.20it/s]
#                    all       3434       4360      0.827      0.813      0.858      0.592
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      49/100      2.38G      1.014     0.9251      1.324         28        640: 100%|██████████| 858/858 [02:37<00:00,  5.44it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:20<00:00,  5.23it/s]
#                    all       3434       4360      0.837       0.81      0.858      0.597
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      50/100      2.38G      1.009     0.9113      1.321         36        640: 100%|██████████| 858/858 [02:37<00:00,  5.44it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:21<00:00,  5.11it/s]
#                    all       3434       4360      0.827      0.811      0.859      0.598
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      51/100      2.38G      1.008     0.9031      1.318         42        640: 100%|██████████| 858/858 [02:38<00:00,  5.42it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:20<00:00,  5.21it/s]
#                    all       3434       4360       0.84      0.811      0.863        0.6
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      52/100      2.38G     0.9944     0.8952      1.311         34        640: 100%|██████████| 858/858 [02:37<00:00,  5.45it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:20<00:00,  5.25it/s]
#                    all       3434       4360      0.828      0.822      0.864      0.603
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      53/100      2.38G      1.001     0.8975       1.32         30        640: 100%|██████████| 858/858 [02:37<00:00,  5.44it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:20<00:00,  5.20it/s]
#                    all       3434       4360      0.842      0.814      0.864      0.603
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      54/100      2.38G      1.001     0.8925      1.316         38        640: 100%|██████████| 858/858 [02:38<00:00,  5.43it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:20<00:00,  5.31it/s]
#                    all       3434       4360      0.824      0.828      0.862      0.603
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      55/100      2.38G     0.9868     0.8792      1.309         36        640: 100%|██████████| 858/858 [02:37<00:00,  5.46it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:20<00:00,  5.22it/s]
#                    all       3434       4360      0.826       0.82      0.861      0.604
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      56/100      2.38G     0.9885     0.8753      1.306         34        640: 100%|██████████| 858/858 [02:37<00:00,  5.46it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:20<00:00,  5.26it/s]
#                    all       3434       4360      0.833       0.82      0.865      0.606
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      57/100      2.38G     0.9851     0.8742      1.299         29        640: 100%|██████████| 858/858 [02:37<00:00,  5.46it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:20<00:00,  5.16it/s]
#                    all       3434       4360      0.839      0.821      0.866      0.606
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      58/100      2.38G     0.9763     0.8591      1.296         45        640: 100%|██████████| 858/858 [02:39<00:00,  5.38it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:20<00:00,  5.19it/s]
#                    all       3434       4360      0.853       0.82      0.868      0.608
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      59/100      2.38G     0.9768     0.8525      1.302         43        640: 100%|██████████| 858/858 [02:38<00:00,  5.42it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:20<00:00,  5.21it/s]
#                    all       3434       4360      0.853      0.815      0.868      0.609
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      60/100      2.38G     0.9697     0.8565      1.294         30        640: 100%|██████████| 858/858 [02:39<00:00,  5.37it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:21<00:00,  5.09it/s]
#                    all       3434       4360      0.848      0.819       0.87       0.61
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      61/100      2.38G     0.9605     0.8403      1.289         35        640: 100%|██████████| 858/858 [02:40<00:00,  5.34it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:21<00:00,  5.03it/s]
#                    all       3434       4360      0.849      0.817       0.87       0.61
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      62/100      2.38G     0.9614     0.8346      1.285         32        640: 100%|██████████| 858/858 [02:38<00:00,  5.42it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:21<00:00,  5.14it/s]
#                    all       3434       4360      0.845       0.82      0.871      0.613
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      63/100      2.38G     0.9608     0.8318      1.287         31        640: 100%|██████████| 858/858 [02:38<00:00,  5.41it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:20<00:00,  5.17it/s]
#                    all       3434       4360      0.859      0.818      0.872      0.615
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      64/100      2.38G      0.951       0.82       1.28         40        640: 100%|██████████| 858/858 [02:38<00:00,  5.42it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:20<00:00,  5.19it/s]
#                    all       3434       4360      0.854      0.822      0.874      0.616
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      65/100      2.38G     0.9501     0.8238      1.281         31        640: 100%|██████████| 858/858 [02:39<00:00,  5.38it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:21<00:00,  5.10it/s]
#                    all       3434       4360      0.853      0.826      0.875      0.618
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      66/100      2.38G     0.9421     0.8102      1.278         37        640: 100%|██████████| 858/858 [02:40<00:00,  5.34it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:21<00:00,  5.14it/s]
#                    all       3434       4360      0.858      0.822      0.876      0.619
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      67/100      2.38G      0.934     0.8029      1.271         46        640: 100%|██████████| 858/858 [02:40<00:00,  5.33it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:21<00:00,  5.06it/s]
#                    all       3434       4360      0.858      0.821      0.876       0.62
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      68/100      2.38G     0.9341     0.8005      1.268         37        640: 100%|██████████| 858/858 [02:41<00:00,  5.31it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:21<00:00,  5.06it/s]
#                    all       3434       4360      0.857      0.823      0.877      0.622
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      69/100      2.38G      0.936     0.7955       1.27         43        640: 100%|██████████| 858/858 [02:40<00:00,  5.33it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:21<00:00,  5.03it/s]
#                    all       3434       4360      0.856      0.824      0.878      0.623
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      70/100      2.38G     0.9346     0.7956      1.266         36        640: 100%|██████████| 858/858 [02:40<00:00,  5.35it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:20<00:00,  5.16it/s]
#                    all       3434       4360      0.855      0.825      0.878      0.623
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      71/100      2.38G     0.9177     0.7794      1.257         38        640: 100%|██████████| 858/858 [02:39<00:00,  5.39it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:20<00:00,  5.21it/s]
#                    all       3434       4360      0.855      0.827      0.878      0.623
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      72/100      2.38G     0.9188     0.7762      1.259         34        640: 100%|██████████| 858/858 [02:38<00:00,  5.40it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:20<00:00,  5.20it/s]
#                    all       3434       4360      0.856      0.829       0.88      0.625
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      73/100      2.38G     0.9124     0.7646      1.253         38        640: 100%|██████████| 858/858 [02:39<00:00,  5.39it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:20<00:00,  5.18it/s]
#                    all       3434       4360      0.859       0.83       0.88      0.625
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      74/100      2.38G     0.9157     0.7692      1.257         44        640: 100%|██████████| 858/858 [02:38<00:00,  5.41it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:21<00:00,  5.08it/s]
#                    all       3434       4360      0.858      0.832       0.88      0.626
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      75/100      2.38G     0.9126      0.769      1.253         34        640: 100%|██████████| 858/858 [02:38<00:00,  5.40it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:20<00:00,  5.15it/s]
#                    all       3434       4360      0.859      0.832      0.881      0.627
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      76/100      2.38G     0.9081     0.7612      1.247         36        640: 100%|██████████| 858/858 [02:39<00:00,  5.40it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:20<00:00,  5.24it/s]
#                    all       3434       4360      0.857      0.831       0.88      0.627
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      77/100      2.38G     0.9069     0.7552      1.247         36        640: 100%|██████████| 858/858 [02:38<00:00,  5.40it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:20<00:00,  5.16it/s]
#                    all       3434       4360      0.861      0.832      0.881      0.627
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      78/100      2.38G     0.8932      0.741      1.237         47        640: 100%|██████████| 858/858 [02:39<00:00,  5.38it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:20<00:00,  5.15it/s]
#                    all       3434       4360      0.862       0.83      0.881      0.628
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      79/100      2.38G     0.8932     0.7407      1.239         27        640: 100%|██████████| 858/858 [02:38<00:00,  5.41it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:21<00:00,  5.14it/s]
#                    all       3434       4360      0.864      0.829      0.881      0.628
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      80/100      2.38G     0.8903     0.7326      1.239         33        640: 100%|██████████| 858/858 [02:39<00:00,  5.40it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:21<00:00,  5.14it/s]
#                    all       3434       4360      0.862      0.831      0.882      0.629
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      81/100      2.38G     0.8838     0.7278      1.235         34        640: 100%|██████████| 858/858 [02:39<00:00,  5.39it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:20<00:00,  5.17it/s]
#                    all       3434       4360      0.858      0.834      0.882       0.63
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      82/100      2.38G     0.8784      0.722      1.231         48        640: 100%|██████████| 858/858 [02:38<00:00,  5.41it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:20<00:00,  5.14it/s]
#                    all       3434       4360      0.855      0.836      0.882       0.63
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      83/100      2.38G     0.8794     0.7189      1.228         44        640: 100%|██████████| 858/858 [02:38<00:00,  5.43it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:20<00:00,  5.18it/s]
#                    all       3434       4360      0.852      0.838      0.883       0.63
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      84/100      2.38G     0.8745     0.7189      1.226         48        640: 100%|██████████| 858/858 [02:38<00:00,  5.43it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:20<00:00,  5.23it/s]
#                    all       3434       4360       0.85      0.841      0.883      0.631
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      85/100      2.38G     0.8704     0.7147      1.225         46        640: 100%|██████████| 858/858 [02:38<00:00,  5.41it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:20<00:00,  5.15it/s]
#                    all       3434       4360      0.847      0.845      0.883      0.631
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      86/100      2.38G     0.8747     0.7133      1.226         31        640: 100%|██████████| 858/858 [02:40<00:00,  5.36it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:21<00:00,  5.11it/s]
#                    all       3434       4360      0.847      0.846      0.883      0.631
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      87/100      2.38G     0.8601     0.6996      1.216         33        640: 100%|██████████| 858/858 [02:39<00:00,  5.37it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:20<00:00,  5.23it/s]
#                    all       3434       4360      0.847      0.846      0.884      0.632
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      88/100      2.38G     0.8572     0.6958      1.216         45        640: 100%|██████████| 858/858 [02:39<00:00,  5.39it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:20<00:00,  5.22it/s]
#                    all       3434       4360      0.847      0.847      0.884      0.633
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      89/100      2.38G     0.8567      0.691      1.212         38        640: 100%|██████████| 858/858 [02:38<00:00,  5.40it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:20<00:00,  5.20it/s]
#                    all       3434       4360      0.848      0.846      0.884      0.633
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      90/100      2.38G     0.8553     0.6881      1.211         39        640: 100%|██████████| 858/858 [02:38<00:00,  5.41it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:20<00:00,  5.21it/s]
#                    all       3434       4360      0.848      0.846      0.885      0.633
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      91/100      2.38G     0.7916      0.532      1.218         19        640: 100%|██████████| 858/858 [02:37<00:00,  5.45it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:21<00:00,  5.12it/s]
#                    all       3434       4360      0.848      0.848      0.885      0.634
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      92/100      2.38G     0.7697     0.5079      1.203         25        640: 100%|██████████| 858/858 [02:35<00:00,  5.52it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:20<00:00,  5.23it/s]
#                    all       3434       4360      0.842      0.851      0.884      0.635
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      93/100      2.38G     0.7612     0.4985      1.198         24        640: 100%|██████████| 858/858 [02:35<00:00,  5.52it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:20<00:00,  5.18it/s]
#                    all       3434       4360      0.844      0.852      0.885      0.636
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      94/100      2.38G     0.7536     0.4884      1.186         19        640: 100%|██████████| 858/858 [02:35<00:00,  5.52it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:20<00:00,  5.18it/s]
#                    all       3434       4360      0.846      0.851      0.885      0.637
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      95/100      2.38G     0.7432     0.4798      1.183         20        640: 100%|██████████| 858/858 [02:35<00:00,  5.51it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:20<00:00,  5.14it/s]
#                    all       3434       4360      0.847      0.851      0.885      0.637
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      96/100      2.38G     0.7374     0.4729      1.176         17        640: 100%|██████████| 858/858 [02:36<00:00,  5.50it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:20<00:00,  5.24it/s]
#                    all       3434       4360      0.847      0.851      0.886      0.638
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      97/100      2.38G     0.7329     0.4727      1.172         26        640: 100%|██████████| 858/858 [02:35<00:00,  5.51it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:21<00:00,  5.12it/s]
#                    all       3434       4360      0.847      0.852      0.886      0.639
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      98/100      2.38G     0.7257     0.4606      1.167         15        640: 100%|██████████| 858/858 [02:35<00:00,  5.52it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:20<00:00,  5.22it/s]
#                    all       3434       4360      0.847      0.852      0.886      0.639
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      99/100      2.38G     0.7171     0.4537      1.163         18        640: 100%|██████████| 858/858 [02:34<00:00,  5.54it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:21<00:00,  5.12it/s]
#                    all       3434       4360      0.845      0.855      0.886       0.64
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     100/100      2.38G     0.7133     0.4512      1.155         20        640: 100%|██████████| 858/858 [02:34<00:00,  5.55it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:20<00:00,  5.26it/s]
#                    all       3434       4360      0.847      0.854      0.887      0.641
# 100 epochs completed in 5.023 hours.
# Optimizer stripped from runs/detect/train/weights/last.pt, 6.3MB
# Optimizer stripped from runs/detect/train/weights/best.pt, 6.3MB
#
# Validating runs/detect/train/weights/best.pt...
# Ultralytics YOLOv8.1.27 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla P100-PCIE-16GB, 16276MiB)
# Model summary (fused): 168 layers, 3008183 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 108/108 [00:23<00:00,  4.61it/s]
#                    all       3434       4360      0.847      0.852      0.887      0.641
#          Autorickshaws       3434        489      0.918      0.967      0.981      0.844
#                  Bench       3434        560      0.869        0.9      0.914      0.666
#              Crosswalk       3434        258      0.898       0.86      0.932       0.72
#            Firehydrant       3434        379      0.975      0.995      0.994      0.726
#                 Person       3434        136      0.689      0.392      0.507      0.323
#              Barricade       3434        308      0.816      0.877      0.917      0.661
#            Garbage box       3434        345      0.885      0.945      0.964      0.805
#                Pothole       3434        337      0.866      0.899      0.939      0.654
#                 Stairs       3434        321      0.863      0.788      0.853      0.625
#           Stray animal       3434        435      0.897      0.904      0.941      0.659
#            green_light       3434        223       0.73      0.826      0.804      0.448
#              red_light       3434        212      0.741      0.784      0.822      0.466
#               vehicles       3434        357      0.859      0.941      0.961      0.735
# Speed: 0.2ms preprocess, 1.9ms inference, 0.0ms loss, 1.0ms postprocess per image
# Results saved to runs/detect/train

# %%
def add_mosaic_marker(ax):
    ax.axvline(mosaic_off_epoch, linestyle="--")
    ax.text(mosaic_off_epoch + 0.5, ax.get_ylim()[1], "mosaic off", va="top")


# Plot A: Train loss curves
plt.figure()
plt.plot(epochs, box_loss, label="box_loss")
plt.plot(epochs, cls_loss, label="cls_loss")
plt.plot(epochs, dfl_loss, label="dfl_loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training losses")
plt.legend()
add_mosaic_marker(plt.gca())
plt.tight_layout()

# Plot B: Validation metrics curves
plt.figure()
plt.plot(epochs, precision, label="Precision (P)")
plt.plot(epochs, recall, label="Recall (R)")
plt.plot(epochs, map50, label="mAP50")
plt.plot(epochs, map50_95, label="mAP50-95")
plt.xlabel("Epoch")
plt.ylabel("Metric")
plt.title("Validation metrics")
plt.legend()
add_mosaic_marker(plt.gca())
plt.tight_layout()

# Plot C: F1 over epochs
plt.figure()
plt.plot(epochs, f1, label="F1")
plt.xlabel("Epoch")
plt.ylabel("F1")
plt.title("F1 score over training")
plt.legend()
add_mosaic_marker(plt.gca())
plt.tight_layout()

# Plot D: Scatter of mAP50 vs mAP50-95 (shows localization quality gap)
plt.figure()
plt.scatter(map50, map50_95)
plt.xlabel("mAP50")
plt.ylabel("mAP50-95")
plt.title("mAP50 vs mAP50-95 scatter (per epoch)")
plt.tight_layout()

# Plot E: Per-class bars for final validation
x = np.arange(len(classes))
w = 0.2

plt.figure(figsize=(12, 5))
plt.bar(x - 1.5*w, cls_P, width=w, label="P")
plt.bar(x - 0.5*w, cls_R, width=w, label="R")
plt.bar(x + 0.5*w, cls_mAP50, width=w, label="mAP50")
plt.bar(x + 1.5*w, cls_mAP5095, width=w, label="mAP50-95")
plt.xticks(x, classes, rotation=45, ha="right")
plt.ylim(0, 1.0)
plt.title("Per-class metrics (final validation)")
plt.legend()
plt.tight_layout()

# Plot F: Identify "hard" classes by mAP50-95 (sorted)
order = np.argsort(cls_mAP5095)
plt.figure(figsize=(10, 5))
plt.bar(np.array(classes)[order], cls_mAP5095[order])
plt.xticks(rotation=45, ha="right")
plt.ylim(0, 1.0)
plt.title("Per-class mAP50-95 (sorted: hard → easy)")
plt.tight_layout()

plt.show()
